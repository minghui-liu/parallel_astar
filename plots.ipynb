# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %% [markdown]
# ### Sequential Timing with Varying K values

# %%
K_list = [4, 8, 16, 32]

#seq_timing = []

# %%
#plot

# %% [markdown]
# ### Charm++ vs MPI

# %%
num_procs = [1, 2, 4, 8, 16, 32]

mpi = [9599, 5083, 2836, 1529, 13541, 25167]
#charmpp

# %%
plt.plot(num_procs, mpi, marker='o', label='MPI')
#plt.plot(num_gpus, charmpp, marker='o', label='Charm++')
plt.title("Execution Time v/s Number of Processes")
plt.legend()
plt.xlabel("Number of Processes")
plt.ylabel("Time (ms)")
# Out:
# Text(0, 0.5, 'Time (ms)')

# %%
#calculate_speedups()
#speedup plot

# %%
#efficiency?

# %%
#same things for rdisc?
